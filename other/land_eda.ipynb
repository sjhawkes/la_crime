# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import missingno as msno
import requests

# %%
land = pd.read_csv('datasets/land.csv')
print(land.shape)
land.head().T
# Out:
# /Users/Sam/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (19,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (3753129, 51)
#                                                                0  \
# ZIPcode                                               90504-3603
# TaxRateArea_CITY                                        TORRANCE
# AIN                                                  4.08503e+09
# RollYear                                                    2014
# TaxRateArea                                                 9340
# AssessorID                                          4085-029-004
# PropertyLocation             4215 W 179TH ST  TORRANCE CA  90504
# PropertyType                                                 SFR
# PropertyUseCode                                             0100
# ...

# %%
msno.bar(land);

# %%
land['RollYear'].hist();

# %%
land['PropertyType'].value_counts()
# Out:
# SFR    1815424
# CND     718763
# R-I     653557
# C/I     293931
# VAC     200266
# OTH      71025
#             10
# Name: PropertyType, dtype: int64
