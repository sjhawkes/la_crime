# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import missingno as msno
import requests

# %%
traf = pd.read_csv('datasets/traffic.csv')
print(traf.shape)
traf.head().T
# Out:
# (528274, 18)
#                                                0                     1  \
# DR Number                              190211527             110518459
# Date Reported                         05/18/2019            10/11/2011
# Date Occurred                         05/18/2019            10/11/2011
# Time Occurred                                110                  1735
# Area ID                                        2                     5
# Area Name                                Rampart                Harbor
# Reporting District                           279                   505
# Crime Code                                   997                   997
# Crime Code Description         TRAFFIC COLLISION     TRAFFIC COLLISION
# MO Codes                3101 3401 3701 3004 3030                  0506
# Victim Age                                    33                    27
# Victim Sex                                     F                     F
# ...
